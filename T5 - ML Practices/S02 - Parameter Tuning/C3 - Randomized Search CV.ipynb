# %% [markdown]
# # Randommized seach CV

# %% [markdown]
# ## Setting up

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Load data
dataObj = load_breast_cancer()
X = dataObj.data
y = dataObj.target

# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X, y, 
    stratify=y,
    test_size=0.30,
    random_state=1)

# %%
from sklearn.svm import SVC

pipe_svc = Pipeline([('scl', StandardScaler()),
            ('clf', SVC(random_state=1))])

# %%
# Get parameter names
for k, v in pipe_svc.get_params().items():
    print(f"{k:35.35s}: {str(v):35.35s}...")
# Out:
# memory                             : None                               ...
# steps                              : [('scl', StandardScaler()), ('clf',...
# verbose                            : False                              ...
# scl                                : StandardScaler()                   ...
# clf                                : SVC(random_state=1)                ...
# scl__copy                          : True                               ...
# scl__with_mean                     : True                               ...
# scl__with_std                      : True                               ...
# clf__C                             : 1.0                                ...
# clf__break_ties                    : False                              ...
# clf__cache_size                    : 200                                ...
# clf__class_weight                  : None                               ...
# clf__coef0                         : 0.0                                ...
# clf__decision_function_shape       : ovr                                ...
# clf__degree                        : 3                                  ...
# clf__gamma                         : scale                              ...
# clf__kernel                        : rbf                                ...
# clf__max_iter                      : -1                                 ...
# clf__probability                   : False                              ...
# clf__random_state                  : 1                                  ...
# clf__shrinking                     : True                               ...
# clf__tol                           : 0.001                              ...
# clf__verbose                       : False                              ...

# %%
param_range = [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0]

set1 = {'clf__C': param_range,
        'clf__kernel': ['linear']}

set2 = {'clf__C': param_range,
        'clf__gamma': param_range,
        'clf__kernel': ['rbf']}

param_grid = [set1, set2]

# %%
from sklearn.model_selection import RandomizedSearchCV

rs = RandomizedSearchCV(estimator=pipe_svc, 
                  param_distributions=param_grid,
                  n_iter = 10,
                  scoring='accuracy', 
                  cv=5,
                  n_jobs=-1)

# %%
rs.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('scl', StandardScaler()),
#                                              ('clf', SVC(random_state=1))]),
#                    n_jobs=-1,
#                    param_distributions=[{'clf__C': [0.0001, 0.001, 0.01, 0.1,
#                                                     1.0, 10.0, 100.0, 1000.0],
#                                          'clf__kernel': ['linear']},
#                                         {'clf__C': [0.0001, 0.001, 0.01, 0.1,
#                                                     1.0, 10.0, 100.0, 1000.0],
#                                          'clf__gamma': [0.0001, 0.001, 0.01,
#                                                         0.1, 1.0, 10.0, 100.0,
#                                                         1000.0],
#                                          'clf__kernel': ['rbf']}],
#                    scoring='accuracy')

# %%
# Get parameter names
for k, v in rs.get_params().items():
    print(f"{k:35.35s}: {str(v):35.35}...")
# Out:
# cv                                 : 5                                  ...
# error_score                        : nan                                ...
# estimator__memory                  : None                               ...
# estimator__steps                   : [('scl', StandardScaler()), ('clf',...
# estimator__verbose                 : False                              ...
# estimator__scl                     : StandardScaler()                   ...
# estimator__clf                     : SVC(random_state=1)                ...
# estimator__scl__copy               : True                               ...
# estimator__scl__with_mean          : True                               ...
# estimator__scl__with_std           : True                               ...
# estimator__clf__C                  : 1.0                                ...
# estimator__clf__break_ties         : False                              ...
# estimator__clf__cache_size         : 200                                ...
# estimator__clf__class_weight       : None                               ...
# estimator__clf__coef0              : 0.0                                ...
# estimator__clf__decision_function_s: ovr                                ...
# estimator__clf__degree             : 3                                  ...
# estimator__clf__gamma              : scale                              ...
# estimator__clf__kernel             : rbf                                ...
# estimator__clf__max_iter           : -1                                 ...
# estimator__clf__probability        : False                              ...
# estimator__clf__random_state       : 1                                  ...
# estimator__clf__shrinking          : True                               ...
# estimator__clf__tol                : 0.001                              ...
# estimator__clf__verbose            : False                              ...
# estimator                          : Pipeline(steps=[('scl', StandardSca...
# n_iter                             : 10                                 ...
# n_jobs                             : -1                                 ...
# param_distributions                : [{'clf__C': [0.0001, 0.001, 0.01, 0...
# pre_dispatch                       : 2*n_jobs                           ...
# random_state                       : None                               ...
# refit                              : True                               ...
# return_train_score                 : False                              ...
# scoring                            : accuracy                           ...
# verbose                            : 0                                  ...

# %%
df = pd.DataFrame(rs.cv_results_)
display(df)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.016153      0.000894         0.006560        0.000462
# 1       0.019400      0.002416         0.007000        0.000895
# 2       0.011400      0.000491         0.005199        0.000400
# 3       0.003799      0.000748         0.001000        0.000632
# 4       0.016680      0.000837         0.006496        0.000561
# 5       0.008999      0.004049         0.003599        0.000800
# 6       0.008607      0.000811         0.004193        0.000403
# 7       0.009393      0.000788         0.004602        0.000490
# 8       0.006200      0.001165         0.002611        0.000478
# 9       0.007401      0.000799         0.003799        0.000402
#
#   param_clf__kernel param_clf__gamma param_clf__C  \
# 0               rbf           1000.0        0.001
# 1               rbf           1000.0          1.0
# 2               rbf             10.0       1000.0
# 3               rbf            0.001       1000.0
# 4               rbf           1000.0          0.1
# 5               rbf              1.0        0.001
# 6               rbf             10.0       0.0001
# 7               rbf              1.0          1.0
# 8               rbf              0.1         10.0
# 9               rbf              0.1        0.001
#
#                                               params  split0_test_score  \
# 0  {'clf__kernel': 'rbf', 'clf__gamma': 1000.0, '...             0.6250
# 1  {'clf__kernel': 'rbf', 'clf__gamma': 1000.0, '...             0.6250
# 2  {'clf__kernel': 'rbf', 'clf__gamma': 10.0, 'cl...             0.6250
# 3  {'clf__kernel': 'rbf', 'clf__gamma': 0.001, 'c...             0.9625
# 4  {'clf__kernel': 'rbf', 'clf__gamma': 1000.0, '...             0.6250
# 5  {'clf__kernel': 'rbf', 'clf__gamma': 1.0, 'clf...             0.6250
# 6  {'clf__kernel': 'rbf', 'clf__gamma': 10.0, 'cl...             0.6250
# 7  {'clf__kernel': 'rbf', 'clf__gamma': 1.0, 'clf...             0.6250
# 8  {'clf__kernel': 'rbf', 'clf__gamma': 0.1, 'clf...             0.9625
# 9  {'clf__kernel': 'rbf', 'clf__gamma': 0.1, 'clf...             0.6250
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0             0.6250             0.6250           0.632911           0.632911
# 1             0.6250             0.6250           0.632911           0.632911
# 2             0.6250             0.6250           0.632911           0.632911
# 3             0.9750             0.9625           0.949367           0.974684
# 4             0.6250             0.6250           0.632911           0.632911
# 5             0.6250             0.6250           0.632911           0.632911
# 6             0.6250             0.6250           0.632911           0.632911
# 7             0.6250             0.6250           0.632911           0.632911
# 8             0.9875             0.9125           0.949367           0.974684
# 9             0.6250             0.6250           0.632911           0.632911
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.628165        0.003876                3
# 1         0.628165        0.003876                3
# 2         0.628165        0.003876                3
# 3         0.964810        0.009492                1
# 4         0.628165        0.003876                3
# 5         0.628165        0.003876                3
# 6         0.628165        0.003876                3
# 7         0.628165        0.003876                3
# 8         0.957310        0.025734                2
# 9         0.628165        0.003876                3

# %%
df = df.sort_values(by=['rank_test_score'])
display(df.head())
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 3       0.003799      0.000748         0.001000        0.000632
# 8       0.006200      0.001165         0.002611        0.000478
# 0       0.016153      0.000894         0.006560        0.000462
# 1       0.019400      0.002416         0.007000        0.000895
# 2       0.011400      0.000491         0.005199        0.000400
#
#   param_clf__kernel param_clf__gamma param_clf__C  \
# 3               rbf            0.001       1000.0
# 8               rbf              0.1         10.0
# 0               rbf           1000.0        0.001
# 1               rbf           1000.0          1.0
# 2               rbf             10.0       1000.0
#
#                                               params  split0_test_score  \
# 3  {'clf__kernel': 'rbf', 'clf__gamma': 0.001, 'c...             0.9625
# 8  {'clf__kernel': 'rbf', 'clf__gamma': 0.1, 'clf...             0.9625
# 0  {'clf__kernel': 'rbf', 'clf__gamma': 1000.0, '...             0.6250
# 1  {'clf__kernel': 'rbf', 'clf__gamma': 1000.0, '...             0.6250
# 2  {'clf__kernel': 'rbf', 'clf__gamma': 10.0, 'cl...             0.6250
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 3             0.9750             0.9625           0.949367           0.974684
# 8             0.9875             0.9125           0.949367           0.974684
# 0             0.6250             0.6250           0.632911           0.632911
# 1             0.6250             0.6250           0.632911           0.632911
# 2             0.6250             0.6250           0.632911           0.632911
#
#    mean_test_score  std_test_score  rank_test_score
# 3         0.964810        0.009492                1
# 8         0.957310        0.025734                2
# 0         0.628165        0.003876                3
# 1         0.628165        0.003876                3
# 2         0.628165        0.003876                3

# %%
print(rs.best_score_)
print(rs.best_params_)
# Out:
# 0.9648101265822785
# {'clf__kernel': 'rbf', 'clf__gamma': 0.001, 'clf__C': 1000.0}

# %% [markdown]
# - Note that grid search already refit the entire training data with the best parameters. You can check this from this setting.

# %%
rs.refit
# Out:
# True

# %%
y_pred = rs.predict(X_test)
testing_accuracy = rs.score(X_test,y_test)
print(f"Testing accuracy: {testing_accuracy:6.3f}")
# Out:
# Testing accuracy:  0.977

# %%
# To do this manually
clf = rs.best_estimator_
clf.fit(X_train, y_train)
testing_accuracy = clf.score(X_test,y_test)
print(f"Testing accuracy: {testing_accuracy:6.3f}")
# Out:
# Testing accuracy:  0.977
