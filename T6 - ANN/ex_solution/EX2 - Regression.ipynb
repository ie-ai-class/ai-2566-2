# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_excel("../data/housing_data.xlsx")
# url = 'https://raw.githubusercontent.com/nnnpooh/ai-class-2565-1/main/Topic%2009%20-%20ANN/data/housing_data.csv'
# df = pd.read_csv(url)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

def reg_plot(ax, X, y, y_pred, title, color="steelblue"):
    ax.scatter(X, y, c=color, edgecolor="white", s=70)
    ax.plot(X, y_pred, color="black", lw=2)
    ax.set_title(title)
    return


def res_plot(ax, y_pred, y, title, color="steelblue"):
    ax.scatter(y_pred, y_pred - y, c=color, marker="o", edgecolor="white", s=70)
    ax.hlines(y=0, xmin=0, xmax=1, color="black", lw=2)
    ax.axes.set_aspect("equal")
    ax.set_title(title)


def store_results(df, model_name, y_train, y_test, y_train_pred, y_test_pred):

    MSE_train = mean_squared_error(y_train, y_train_pred)
    MSE_test = mean_squared_error(y_test, y_test_pred)

    R2_train = r2_score(y_train, y_train_pred)
    R2_test = r2_score(y_test, y_test_pred)

    data = {
        "Model": model_name,
        "MSE Train": [MSE_train],
        "MSE Test": [MSE_test],
        "R2 Train": [R2_train],
        "R2 Test": [R2_test],
    }
    dft = pd.DataFrame(data=data)
    return df.append(dft, ignore_index=True)

# %%
# Extract data
colsX = [i for i in df.columns if i != 'MEDV']
X = df[colsX].values
y = df["MEDV"].values
print(X.shape)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
# Out:
# (506, 13)

# %% [markdown]
# Very important to scale both X and y data.

# %%
# Standardization
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# Scale y data
nm = MinMaxScaler()
y_train = y_train.reshape(-1, 1) # Required for sklearn api
y_test = y_test.reshape(-1, 1)
nm.fit(y_train)
y_train_scaled = nm.transform(y_train)
y_test_scaled = nm.transform(y_test)

# %%
tf.keras.backend.clear_session()

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(13,)),
    tf.keras.layers.Dense(units=16, activation='relu', name='hidden1'),
    tf.keras.layers.Dense(units=1, name='output')
    ])

model.summary()

model.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=['mean_absolute_percentage_error'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden1 (Dense)              (None, 16)                224
# _________________________________________________________________
# output (Dense)               (None, 1)                 17
# =================================================================
# Total params: 241
# Trainable params: 241
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf_fit = model.fit(x=X_train_std, y=y_train_scaled,
        batch_size=16,
        validation_split=0.1,
        epochs=100, 
        verbose=1)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.3821 - mean_absolute_percentage_error: 2787682.0000 - val_loss: 0.2964 - val_mean_absolute_percentage_error: 149.2925
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2638 - mean_absolute_percentage_error: 3988788.0000 - val_loss: 0.2119 - val_mean_absolute_percentage_error: 120.4390
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1957 - mean_absolute_percentage_error: 3336986.2500 - val_loss: 0.1516 - val_mean_absolute_percentage_error: 99.7170
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1453 - mean_absolute_percentage_error: 2595928.7500 - val_loss: 0.1101 - val_mean_absolute_percentage_error: 85.1218
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1091 - mean_absolute_percentage_error: 2014157.6250 - val_loss: 0.0830 - val_mean_absolute_percentage_error: 76.9061
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0843 - mean_absolute_percentage_error: 1483172.3750 - val_loss: 0.0641 - val_mean_absolute_percentage_error: 70.9389
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0649 - mean_absolute_percentage_error: 1518987.6250 - val_loss: 0.0527 - val_mean_absolute_percentage_error: 59.6931
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0525 - mean_absolute_percentage_error: 1285568.2500 - val_loss: 0.0430 - val_mean_absolute_percentage_error: 55.9020
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0437 - mean_absolute_percentage_error: 1175219.3750 - val_loss: 0.0375 - val_mean_absolute_percentage_error: 50.3667
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0380 - mean_absolute_percentage_error: 1199158.2500 - val_loss: 0.0324 - val_mean_absolute_percentage_error: 47.8261
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0334 - mean_absolute_percentage_error: 1049132.6250 - val_loss: 0.0292 - val_mean_absolute_percentage_error: 45.2946
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0301 - mean_absolute_percentage_error: 1074455.6250 - val_loss: 0.0268 - val_mean_absolute_percentage_error: 41.9396
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0278 - mean_absolute_percentage_error: 878984.6250 - val_loss: 0.0246 - val_mean_absolute_percentage_error: 41.3857
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0256 - mean_absolute_percentage_error: 801429.7500 - val_loss: 0.0226 - val_mean_absolute_percentage_error: 38.8975
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0237 - mean_absolute_percentage_error: 790631.1875 - val_loss: 0.0209 - val_mean_absolute_percentage_error: 38.4329
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0222 - mean_absolute_percentage_error: 713380.5000 - val_loss: 0.0198 - val_mean_absolute_percentage_error: 36.6013
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0208 - mean_absolute_percentage_error: 698430.0000 - val_loss: 0.0181 - val_mean_absolute_percentage_error: 36.5937
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0197 - mean_absolute_percentage_error: 727819.7500 - val_loss: 0.0172 - val_mean_absolute_percentage_error: 34.6644
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0184 - mean_absolute_percentage_error: 786604.5000 - val_loss: 0.0162 - val_mean_absolute_percentage_error: 34.2129
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0177 - mean_absolute_percentage_error: 936314.1875 - val_loss: 0.0152 - val_mean_absolute_percentage_error: 32.3063
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0168 - mean_absolute_percentage_error: 810892.2500 - val_loss: 0.0146 - val_mean_absolute_percentage_error: 31.7791
# Epoch 22/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0158 - mean_absolute_percentage_error: 692890.5625 - val_loss: 0.0137 - val_mean_absolute_percentage_error: 32.0156
# Epoch 23/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0150 - mean_absolute_percentage_error: 559682.1875 - val_loss: 0.0132 - val_mean_absolute_percentage_error: 31.7875
# Epoch 24/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0144 - mean_absolute_percentage_error: 661272.9375 - val_loss: 0.0126 - val_mean_absolute_percentage_error: 29.8058
# Epoch 25/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 593069.8750 - val_loss: 0.0119 - val_mean_absolute_percentage_error: 29.0304
# Epoch 26/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0133 - mean_absolute_percentage_error: 678322.4375 - val_loss: 0.0115 - val_mean_absolute_percentage_error: 28.8427
# Epoch 27/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0126 - mean_absolute_percentage_error: 703208.4375 - val_loss: 0.0111 - val_mean_absolute_percentage_error: 28.2022
# Epoch 28/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0122 - mean_absolute_percentage_error: 636769.2500 - val_loss: 0.0107 - val_mean_absolute_percentage_error: 27.8428
# Epoch 29/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0118 - mean_absolute_percentage_error: 501794.7188 - val_loss: 0.0105 - val_mean_absolute_percentage_error: 28.0183
# Epoch 30/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0113 - mean_absolute_percentage_error: 754551.0000 - val_loss: 0.0099 - val_mean_absolute_percentage_error: 26.9681
# Epoch 31/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0108 - mean_absolute_percentage_error: 557356.8125 - val_loss: 0.0095 - val_mean_absolute_percentage_error: 26.9510
# Epoch 32/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0103 - mean_absolute_percentage_error: 702488.6250 - val_loss: 0.0093 - val_mean_absolute_percentage_error: 26.3877
# Epoch 33/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0099 - mean_absolute_percentage_error: 566400.6875 - val_loss: 0.0090 - val_mean_absolute_percentage_error: 25.6690
# Epoch 34/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0095 - mean_absolute_percentage_error: 522489.0625 - val_loss: 0.0090 - val_mean_absolute_percentage_error: 26.6982
# Epoch 35/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0092 - mean_absolute_percentage_error: 475080.5938 - val_loss: 0.0084 - val_mean_absolute_percentage_error: 25.2227
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0089 - mean_absolute_percentage_error: 682257.0000 - val_loss: 0.0082 - val_mean_absolute_percentage_error: 25.3235
# Epoch 37/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0086 - mean_absolute_percentage_error: 601660.7500 - val_loss: 0.0080 - val_mean_absolute_percentage_error: 25.1082
# Epoch 38/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0083 - mean_absolute_percentage_error: 478573.1875 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 25.3781
# Epoch 39/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0080 - mean_absolute_percentage_error: 522974.0000 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 23.4848
# Epoch 40/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0079 - mean_absolute_percentage_error: 486252.8438 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 24.6213
# Epoch 41/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_percentage_error: 645490.9375 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 24.6116
# Epoch 42/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0075 - mean_absolute_percentage_error: 536003.3750 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 23.1822
# Epoch 43/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_percentage_error: 605691.7500 - val_loss: 0.0070 - val_mean_absolute_percentage_error: 24.0805
# Epoch 44/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_percentage_error: 337838.6562 - val_loss: 0.0069 - val_mean_absolute_percentage_error: 23.5040
# Epoch 45/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_absolute_percentage_error: 556407.5625 - val_loss: 0.0067 - val_mean_absolute_percentage_error: 24.0871
# Epoch 46/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0068 - mean_absolute_percentage_error: 512949.0312 - val_loss: 0.0067 - val_mean_absolute_percentage_error: 24.1956
# Epoch 47/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0065 - mean_absolute_percentage_error: 446672.3125 - val_loss: 0.0065 - val_mean_absolute_percentage_error: 23.9675
# Epoch 48/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0065 - mean_absolute_percentage_error: 529272.8750 - val_loss: 0.0065 - val_mean_absolute_percentage_error: 22.2876
# Epoch 49/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0065 - mean_absolute_percentage_error: 491795.9375 - val_loss: 0.0064 - val_mean_absolute_percentage_error: 22.7381
# Epoch 50/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0061 - mean_absolute_percentage_error: 479682.2500 - val_loss: 0.0063 - val_mean_absolute_percentage_error: 24.0657
# Epoch 51/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0060 - mean_absolute_percentage_error: 274722.7188 - val_loss: 0.0063 - val_mean_absolute_percentage_error: 22.9771
# Epoch 52/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0058 - mean_absolute_percentage_error: 617594.1250 - val_loss: 0.0061 - val_mean_absolute_percentage_error: 23.0579
# Epoch 53/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_percentage_error: 361221.0938 - val_loss: 0.0060 - val_mean_absolute_percentage_error: 23.1636
# Epoch 54/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0056 - mean_absolute_percentage_error: 386463.6875 - val_loss: 0.0062 - val_mean_absolute_percentage_error: 23.4364
# Epoch 55/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0055 - mean_absolute_percentage_error: 459263.3438 - val_loss: 0.0061 - val_mean_absolute_percentage_error: 23.7040
# Epoch 56/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_percentage_error: 404311.6250 - val_loss: 0.0060 - val_mean_absolute_percentage_error: 23.8314
# Epoch 57/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_percentage_error: 500707.2812 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 23.8792
# Epoch 58/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_percentage_error: 335581.8125 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 24.0113
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0051 - mean_absolute_percentage_error: 473170.4062 - val_loss: 0.0058 - val_mean_absolute_percentage_error: 24.4769
# Epoch 60/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0050 - mean_absolute_percentage_error: 313667.6250 - val_loss: 0.0060 - val_mean_absolute_percentage_error: 24.0281
# Epoch 61/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0049 - mean_absolute_percentage_error: 504376.9688 - val_loss: 0.0058 - val_mean_absolute_percentage_error: 24.3830
# Epoch 62/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_percentage_error: 439617.2188 - val_loss: 0.0057 - val_mean_absolute_percentage_error: 24.8924
# Epoch 63/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_percentage_error: 321163.0625 - val_loss: 0.0058 - val_mean_absolute_percentage_error: 25.0423
# Epoch 64/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_percentage_error: 286777.1875 - val_loss: 0.0057 - val_mean_absolute_percentage_error: 24.5715
# Epoch 65/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0046 - mean_absolute_percentage_error: 340870.0000 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 25.0034
# Epoch 66/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0045 - mean_absolute_percentage_error: 400168.4688 - val_loss: 0.0058 - val_mean_absolute_percentage_error: 24.8005
# Epoch 67/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0045 - mean_absolute_percentage_error: 402920.6875 - val_loss: 0.0057 - val_mean_absolute_percentage_error: 25.4823
# Epoch 68/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0044 - mean_absolute_percentage_error: 362690.3750 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 24.3649
# Epoch 69/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0043 - mean_absolute_percentage_error: 468424.9688 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 24.7534
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0043 - mean_absolute_percentage_error: 379130.1562 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 25.0625
# Epoch 71/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_percentage_error: 362759.4688 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 25.7730
# Epoch 72/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0042 - mean_absolute_percentage_error: 324930.9062 - val_loss: 0.0057 - val_mean_absolute_percentage_error: 25.4558
# Epoch 73/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0041 - mean_absolute_percentage_error: 330296.8438 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 24.8572
# Epoch 74/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0041 - mean_absolute_percentage_error: 349651.2500 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 25.3761
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0041 - mean_absolute_percentage_error: 371922.2812 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 25.0503
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_percentage_error: 357639.4062 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 26.0164
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0040 - mean_absolute_percentage_error: 471634.7812 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 24.8615
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0039 - mean_absolute_percentage_error: 332772.7188 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 24.8362
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_percentage_error: 340284.5938 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 25.2501
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_percentage_error: 318314.0000 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 25.4202
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0038 - mean_absolute_percentage_error: 361012.9375 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 24.8742
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_percentage_error: 307354.1875 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 25.3985
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_percentage_error: 345118.1875 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 25.3125
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_percentage_error: 244547.5469 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 24.9963
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0037 - mean_absolute_percentage_error: 377900.8438 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 24.7797
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_percentage_error: 298629.3438 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 25.0977
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_percentage_error: 304643.2500 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 25.2761
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0036 - mean_absolute_percentage_error: 290652.8438 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 24.6186
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_percentage_error: 337405.6250 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 25.1113
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_percentage_error: 257295.7188 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 24.3085
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_percentage_error: 315248.1875 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 24.7507
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_percentage_error: 331686.6562 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 24.6181
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_percentage_error: 366318.3125 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 24.5557
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_percentage_error: 279298.6562 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 25.0690
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_percentage_error: 457506.0000 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 25.1608
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0034 - mean_absolute_percentage_error: 301967.0938 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 23.9097
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_percentage_error: 367165.3750 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 26.4290
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0035 - mean_absolute_percentage_error: 553910.3125 - val_loss: 0.0053 - val_mean_absolute_percentage_error: 25.6793
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0033 - mean_absolute_percentage_error: 418234.1250 - val_loss: 0.0052 - val_mean_absolute_percentage_error: 24.3155
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0032 - mean_absolute_percentage_error: 329893.3438 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 24.8662

# %%
hist = tf_fit.history

fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(1, 2, 1)
ax.plot(hist['loss'], lw=3)
ax.plot(hist['val_loss'], lw=3)
ax.set_title('Training loss', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.legend(['train','val'])

ax = fig.add_subplot(1, 2, 2)
ax.plot(hist['mean_absolute_percentage_error'], lw=3)
ax.plot(hist['val_mean_absolute_percentage_error'], lw=3)
ax.set_title('Training MAPE', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
ax.legend(['train','val'])

# %%
y_train_pred = model.predict(X_train_std)
y_test_pred = model.predict(X_test_std)

# %%
df = store_results(
    df=pd.DataFrame(),
    model_name='ANN',
    y_train=y_train_scaled,
    y_train_pred=y_train_pred,
    y_test=y_test_scaled,
    y_test_pred=y_test_pred,
)
# Out:
# C:\Users\nnnpo\AppData\Local\Temp\ipykernel_22856\4189812546.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return df.append(dft, ignore_index=True)

# %%
display(df)
# Out:
#   Model  MSE Train  MSE Test  R2 Train   R2 Test
# 0   ANN   0.003314  0.012016   0.92082  0.707783
