# %%
from matplotlib import pyplot as plt
import numpy as np
from aeon.utils.plotting import plot_series
from aeon.datasets import load_airline
from aeon.forecasting.model_selection import temporal_train_test_split
from aeon.performance_metrics.forecasting import mean_absolute_percentage_error
from aeon.forecasting.bats import BATS

# %%
y = load_airline()
y_train, y_test = temporal_train_test_split(y, test_size=36)

fh = np.arange(1, 37)

# %%
forecaster = BATS(sp=12, use_trend=True, use_box_cox=True, use_damped_trend=True, use_arma_errors=True)

# %%
forecaster.fit(y_train)
# Out:
# BATS(sp=12, use_box_cox=True, use_damped_trend=True, use_trend=True)

# %%
forecaster.get_params()
# Out:
# {'box_cox_bounds': (0, 1),
#  'context': None,
#  'multiprocessing_start_method': 'spawn',
#  'n_jobs': None,
#  'show_warnings': True,
#  'sp': 12,
#  'use_arma_errors': True,
#  'use_box_cox': True,
#  'use_damped_trend': True,
#  'use_trend': True}

# %%
y_pred = forecaster.predict(fh)

# %%
plot_series(y_train, y_test, y_pred, labels=["y_train", "y_test", "y_pred"])
# Out:
# (<Figure size 1600x400 with 1 Axes>,
#  <Axes: ylabel='Number of airline passengers'>)

# %%
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.12160582219846432

# %%
from aeon.forecasting.tbats import TBATS

# %%
forecaster = TBATS(sp=12, use_trend=True, use_box_cox=True, use_damped_trend=True, use_arma_errors=True)

# %%
forecaster.fit(y_train)
# Out:
# TBATS(sp=12, use_box_cox=True, use_damped_trend=True, use_trend=True)

# %%
y_pred = forecaster.predict(fh)

# %%
plot_series(y_train, y_test, y_pred, labels=["y_train", "y_test", "y_pred"])
# Out:
# (<Figure size 1600x400 with 1 Axes>,
#  <Axes: ylabel='Number of airline passengers'>)

# %%
mean_absolute_percentage_error(y_test, y_pred)
# Out:
# 0.051225667048981946
